# %%
a = 12
b = 2
print("Addition:", a + b)
print("Exponent (12 squared):", a ** b)
print("Division:", a / b)
# Out:
# Addition: 14
# Exponent (12 squared): 144
# Division: 6.0

# %%
import numpy as np

print("Pi Constant:", np.pi)
print("Euler's Number (e):", np.e)
print("Sine of 45 degrees:", np.sin(np.pi / 4))
# Out:
# Pi Constant: 3.141592653589793
# Euler's Number (e): 2.718281828459045
# Sine of 45 degrees: 0.7071067811865475

# %%
# A dictionary tracking molecular weights for engineering tasks
mw = {'CH4': 16.04, 'H2O': 18.02, 'O2': 32.00, 'CO2': 44.01}

print("Molar mass of Methane:", mw['CH4'])
# Out:
# Molar mass of Methane: 16.04
